# %% [markdown]
# # Barplot

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('fivethirtyeight')

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x = 'day', y = 'tip', data = tips)
plt.show()

# %%
sns.barplot(x = 'day', y = 'tip', data = tips, palette = 'spring', order = ['Sat', 'Sun', 'Thur', 'Fri'])
plt.show()

# %%
sns.barplot(x = 'day', y = 'tip', data = tips, hue = 'sex', palette = 'winter_r')
plt.show()

# %%
sns.barplot(x = 'tip', y = 'day', data = tips, palette = 'winter_r', hue = 'sex')

# %% [markdown]
# # Catplot

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips)
plt.show()

# %%
sns.catplot(x = 'total_bill', y = 'day', data = tips, jitter = False)
plt.show()

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex')
plt.show()

# %% [markdown]
# # Swarmplot

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex')
plt.show()

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data = tips, order = ['Sat', 'Sun', 'Thur', 'Fri'], hue = 'sex')
plt.show()

# %% [markdown]
# # Violinplot

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.violinplot(x = 'total_bill', y = 'day', data = tips, hue = 'smoker')
plt.show()

# %%
sns.violinplot(x = 'total_bill', y = 'day', data = tips, hue = 'smoker', split = True, inner = 'stick')
plt.show()
